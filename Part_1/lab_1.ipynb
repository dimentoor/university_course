# %% [markdown]
# # Лабораторная работа №1
# ### Шифр Цезаря
# Дан следующий текст на русском языке:
# «закон об информации информационных технологиях и защите информации» и различные варианты на английском (из файла)
#
# ### Задания:
# 1.   Допишите программу на языке Python (или напишите на любом другом языке программирования), которая выполняет <b>шифрование</b> данного текста с помощью шифра Цезаря.
# 2.   Допишите программу на языке Python (или напишите на любом другом языкепрограммирования), которая выполняет <b>дешифровку</b>  данного текста с помощью шифра Цезаря. Выведите на экран все 33 (26 для английского языка) варианта дешифрованного текста (см. таблицу 1 из файла).
# 3. Найдите среди результатов осмысленную фразу.
# 4. Запишите найденный ключ и исходный открытый текст.
#
# Исходный алфавиты: <br>
# русский - "АБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯ" <br>
# английский - "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
# <br>
# <br>
# <br>
# файл с материалом по шифру конечно лучше оформить прям тут в документе

# %% [markdown]
# Часть 1 - Шифрование сообщения (задается сообщение и ключ)

# %%
alphabet = "АБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯ"
alphabet_eng = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

def caesar_encrypt(text, shift):
    """Шифрование Цезаря"""
    result = ""
    # your code here
    return result


original_text = "закон об информации информационных технологиях и защите информации"
original_text_eng = "The only thing we have to fear is fear itself" # ваш вариант
key = 21 # сдвиг

# Шифрование
encrypted_text = caesar_encrypt(original_text, key)
# encrypted_text_eng = caesar_encrypt(original_text_eng, key) - # английский

print("Зашифрованный текст:", encrypted_text)
# Out:
# Зашифрованный текст: ьфягв гх эвигебфкээ эвигебфкэгввпй жщйвгагчэуй э ьфнэжщ эвигебфкээ

# %% [markdown]
# часть 2

# %%
def caesar_decrypt(text, shift):
    """Дешифрование Цезаря"""
    result = ""
    # your code here
    return result

def brute_force(cipher):
    """Перебор всех ключей"""
    results = []
    # your code here
    return results


print("\nПопытки расшифровки:")
for k, txt in brute_force(encrypted_text):
    print(f"Ключ {k:2}: {txt}")
# Out:
# Попытки расшифровки:
# Ключ  1: ыуювб вф ьбзвдауйьь ьбзвдауйьвббои ёшибвявцьти ь ыумьёш ьбзвдауйьь
# Ключ  2: ътэба бу ыажбгятиыы ыажбгятиыбаанз ечзабюбхысз ы ътлыеч ыажбгятиыы
# Ключ  3: щсьая ат ъяёавюсзъъ ъяёавюсзъаяямж дцжяаэафърж ъ щскъдц ъяёавюсзъъ
# Ключ  4: шрыяю яс щюеябэржщщ щюеябэржщяююлё гхёюяьяущпё щ шрйщгх щюеябэржщщ
# Ключ  5: чпъюэ юр шэдюаьпёшш шэдюаьпёшюээке вфеэюыютшое ш чпишвф шэдюаьпёшш
# Ключ  6: цощэь эп чьгэяыоечч чьгэяыоечэььйд будьэъэсчнд ч цозчбу чьгэяыоечч
# Ключ  7: хншьы ьо цывьюъндцц цывьюъндцьыыиг атгыьщьрцмг ц хнжцат цывьюъндцц
# Ключ  8: фмчыъ ын хъбыэщмгхх хъбыэщмгхыъъзв ясвъышыпхлв х фмёхяс хъбыэщмгхх
# Ключ  9: улцъщ ъм фщаъьшлвфф фщаъьшлвфъщщжб юрбщъчъофкб ф улефюр фщаъьшлвфф
# Ключ 10: ткхщш щл ушящычкбуу ушящычкбущшшёа эпашщцщнуйа у ткдуэп ушящычкбуу
# Ключ 11: сйфшч шк тчюшъцйатт тчюшъцйатшччея ьоячшхшмтия т сйгтьо тчюшъцйатт
# Ключ 12: риучц чй сцэчщхиясс сцэчщхиясчццдю ынюцчфчлсзю с ривсын сцэчщхиясс
# ...
